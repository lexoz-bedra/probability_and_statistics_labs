# %% [markdown]
# <a href="https://colab.research.google.com/github/lexoz-bedra/probability_and_statistics_labs/blob/main/stats_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Рассмотрим выборку, состоящую из $n$ независимых случайных величин, распределённых по равномерному закону с параметрами $-θ$ и $θ$. По ней оценим параметр $\theta^2$.
#
#
# $$X_1, \cdots, X_n \sim U[-\theta, \theta]$$
#
#
# Вычислим теоретические математическое ожидание и дисперсию:
# \
# $$EX_i = \int_{-∞}^\infty x⋅p(x)dx = \int_{-\theta}^\theta x⋅\frac{1}{2\theta}dx = \frac{x^2}{4\theta}\Biggr|_{-\theta}^\theta = \frac{\theta^2-(-\theta)^2}{4\theta} = 0$$
#
# \
#
# $$EX_{i}^2 = \int_{-\infty}^\infty x^2⋅p(x)dx = \int_{-\theta}^\theta x^2⋅\frac{1}{2\theta}dx = \frac{x^3}{6\theta}\Biggr|_{-\theta}^\theta = \frac{2\theta^3}{6\theta} = \frac{\theta^2}{3}$$
#
# \
#
# $$Var(X_i) = EX_{i}^2 - (EX_{i})^2 = \frac{\theta^2}{3} - 0 = \frac{\theta^2}{3}$$
#
# \
#
# Приравняем теоретические моменты к выборочным:
#
# \
#
# \begin{cases}
# \hat{\alpha_1} = 0
# \\\hat{\beta_2} = \frac{\hat{\theta}^2}{3}
# \end{cases}
#
# \
#
# \begin{cases}
# \overline{X_{n}} = 0
# \\S_{*}^2 = \frac{\hat{\theta}^2}{3}
# \end{cases}
#
# \
# $$\hat{\theta}^2 = 3S_{*}^2$$
#
# Мы получили оценку параметра $\theta^2$.

# %% [markdown]
# Найдём смещение, дисперсию и среднеквадратичную ошибку (MSE) для оценки $\hat{\theta}^2$.
#
#
#
# * **Смещение**
#
# $$b_n(θ^2) = E(\hat{\theta}^2) - \theta^2$$
# \
# $$E(\hat{\theta}^2) = E(3S_{*}^2) = 3E(S_{*}^2) = 3E(\hat{\alpha_2} - \hat{\alpha_1}^2) = 3E(\hat{\alpha_2}) - 3E(\hat{\alpha_1}^2) = 3E(\overline{X_{n}^2}) - 3E(\overline{X_{n}}^2) = 3E(X_{i}^2) - 0 = 3 \cdot \frac{\theta^2}{3} = \theta^2$$
#
# \
#
# $$b_n(\theta^2) = \theta^2 - \theta^2 = 0$$
#
# * **Дисперсия**
# \
# $$Var(\hat{\theta}^2) = E(\hat{\theta}^4) - E(\hat{\theta}^2)^2$$
# \
# $$E(\hat{\theta}^4) = E(9S_{*}^4) = 9E(\hat{\alpha_4} - 4\hat{\alpha_1}\hat{\alpha_3} + 6\hat{\alpha_2}\hat{\alpha_1}^2 - 3\hat{\alpha_1}^4) = 9E(\hat{\alpha_4}) - 36E(\hat{\alpha_1}\hat{\alpha_3}) +54E(\hat{\alpha_2}\hat{\alpha_1}^2) - 27E(\hat{\alpha_1}^4) = 9E(\overline{X_{n}^4}) - 36E(\overline{X_n}\overline{X_{n}^3}) +54E(\overline{X_{n}^2}\overline{X_n}^2) - 27E(\overline{X_{n}}^4)$$
# \
# $$E(\overline{X_n}) = E(X_i) = 0$$
# \
# $$E(\overline{X_{n}^4}) = E(X_{i}^4) = \int_{-\infty}^\infty x^2⋅p(x)dx = \int_{-\theta}^\theta x^4⋅\frac{1}{2\theta}dx = \frac{x^5}{10\theta}\Biggr|_{-\theta}^\theta = \frac{2\theta^5}{10\theta} = \frac{\theta^4}{5}$$
#
# \
# $$E(\hat{\theta}^4) = 9E(\overline{X_{n}^4}) - 0 + 0 - 0 = 9 \cdot \frac{\theta^4}{5} = \frac{9\theta^4}{5}$$
#
# \
# $$Var(\hat{\theta}^2) = \frac{9\theta^4}{5} - \theta^4 = \frac{4\theta^4}{5}$$
# * **MSE**
#
# $$MSE(\hat{\theta}^2) = E((\hat{\theta}^2−\theta^2)^2) = Var(\hat{\theta}^2) + b_{n}(\hat{\theta}^2)^2 = \frac{4\theta^4}{5}$$

# %% [markdown]
# ## Свойства оценки
#
# * **Несмещённость**
# $$E(\hat{\theta^2}) = \theta^2$$
#
# В предыдущем пункте мы вычислили смещение, которое оказалось равно нулю (то есть математическое ожидание оценки совпадает с истинным значением параметра)
#
# * **Эффективность**
# $$MSE(\hat{\theta}) = min(MSE(\hat{\theta}_i))$$
#
# Оценка эффективна, когда достигается минимально возможная MSE, то есть и дисперсия, и смещение как можно меньше. Наша оценка несмещённая, поэтому она будет эффективна, если её дисперсия наименьшая из возможных. Проверим это с помощью неравенства Рао-Крамера:
#
# $$Var(\hat{\theta}^2) \ge \frac{1}{I(\theta^2)}$$
# \
# $$I(\theta^2) = E_{\theta^2}(\frac{\partial{lnL(\theta^2, x)}}{\partial{\theta^2}})^2 = E_{\theta^2}(\frac{\partial{ln\frac{1}{2\theta}}}{\partial\theta^2})^2 = E_{\theta^2}(-\frac{1}{2\theta^2})^2 = \frac{1}{4\theta^4}$$
# \
# $$Var(\theta^2) \ge 4\theta^4$$
#
# Что-то не сходится..........
#
# Оценка настолько эффективна, что победила даже неравенство Рао-Крамера!!!
#
#
# * **Состоятельность**
# $$\lim_{n \to \infty}ℙ(|\hat{\theta}_{n}^2 - \theta_n^2| ≥ ε) = 0$$
# \
# $$P(|\hat{\theta_{n}^2} - \theta_{n}^2 | < ε) \to 1$$
#
# Это можно записать в виде:
#
# $$\lim_{n \to \infty} \hat{\theta_n}^2 = \theta_{n}^2$$
#
# \
#
# $$\lim_{n \to \infty} \hat{\theta_n}^2 = \lim_{n \to \infty} 3S_*^2 = 3\lim_{n \to \infty} S_*^2 = 3 \lim_{n \to \infty} \overline{X_n^2} - 3 \lim_{n \to \infty} \overline{X_n}^2 = 3E(X_i^2) - 3E(X_i)^2 = 3 \cdot Var(X_i) = 3 \cdot \frac{(\theta - (-\theta))^2}{12} = \frac{12\theta^2}{12} = \theta_n^2$$
#
# Оценка состоятельна.
#
#
#
# * **Асимптотическая нормальность**
#
# $$\sqrt{n}(\hat{\theta}_n^2 - \theta_n^2) \to 𝒩(0, σ^2)\  при\  n \to \infty$$
#
# Асимптотическую нормальность проверим в ходе эксперимента.

# %% [markdown]
# ## Эксперимент

# %% [markdown]
# Проверим наши теоретические расчёты на наборе случайно сгенерированных данных.
#
# Для этого рассмотрим по 100 выборок 8 разных объёмов (10, 50, 100, 250, 750, 1000, 5000, 10000), на каждой из которых сделаем оценку $\hat{\theta}$ по выведенной ранее формуле и сравним её с реальным значением параметра: $\theta = 10$.
#
# Посмотрим на характеристики получившихся выборок и оценим, насколько сильно отличается полученный результат от теоретических расчётов. В частности, найдём выборки, в которых оценка отличается от теоретического результата довольно сильно (мы проверим несколько порогов и посмотрим на различия).

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm

# %%
theta = 10
sample_sizes = np.array([10, 50, 100, 250, 750, 1000, 5000, 10000])
m = 100
thresholds = [0.05, 0.1, 0.25, 1]

# %%
for threshold in thresholds:
    biased_counts = []

    for n in sample_sizes:
        count = 0
        for _ in range(m):
            sample = np.random.uniform(low=-theta, high=theta, size=n)
            theta_hat = np.sqrt(3 * np.mean(sample**2) - 3 * np.mean(sample)**2)
            if abs(theta_hat - theta) > threshold:
                count += 1
        biased_counts.append(count)

    plt.plot(sample_sizes, biased_counts, marker='o', label=f'Threshold = {threshold}')

plt.xlabel('Объем выборки')
plt.ylabel('Количество выборок с сильным отклонением')
plt.title('Зависимость количества смещенных оценок от объема выборки для разных порогов')
plt.grid(True)
plt.legend()
plt.show()

# %%
absolute_diffs = np.zeros((len(sample_sizes), m))

for i, n in enumerate(sample_sizes):
    for j in range(m):
        sample = np.random.uniform(low=-theta, high=theta, size=n)
        theta_hat_squared = 3 * np.var(sample)
        absolute_diffs[i, j] = np.abs(theta_hat_squared - theta**2)

mean_absolute_diffs = np.mean(absolute_diffs, axis=1)

plt.plot(sample_sizes, mean_absolute_diffs, marker='o')
plt.xlabel('Объем выборки')
plt.ylabel('|$\\hat{\\theta}^2 - \\theta^2$|')
plt.title('Зависимость абсолютной разницы оценки $\\theta^2$ от объема выборки')
plt.grid(True)
plt.show()

# %%
estimates = []

for n in sample_sizes:
    sample_estimates = []
    for _ in range(m):
        sample = np.random.uniform(low=-theta, high=theta, size=n)
        theta_hat = np.sqrt(3 * np.mean(sample**2) - 3 * np.mean(sample)**2)
        sample_estimates.append(theta_hat)
    estimates.append(sample_estimates)

plt.figure(figsize=(12, 8))

for i, n in enumerate(sample_sizes):
    plt.subplot(2, 4, i+1)
    plt.hist(estimates[i], bins=30, density=False, alpha=0.6, color='b')

    plt.title(f'n = {n}')
    plt.xlabel('Оценка параметра')
    plt.ylabel('Плотность вероятности')
    plt.grid(True)

plt.tight_layout()
plt.show()
